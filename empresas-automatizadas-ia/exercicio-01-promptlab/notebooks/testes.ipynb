# %% [markdown]
# # Testes — Exercício 01 PromptLab
#
# Com o serviço a correr (`docker compose up --build`), execute as células seguintes.

# %%
import json
import urllib.request

BASE = "http://localhost:8000"


def post(path: str, payload: dict) -> dict:
    data = json.dumps(payload).encode("utf-8")
    req = urllib.request.Request(
        BASE + path,
        data=data,
        headers={"Content-Type": "application/json"},
        method="POST",
    )
    with urllib.request.urlopen(req, timeout=120) as resp:
        return json.loads(resp.read().decode("utf-8"))

# %%
with urllib.request.urlopen(BASE + "/health", timeout=10) as r:
    print(r.read().decode())

# %%
for perfil in ("tecnico", "professor", "comercial", "sarcastico_nerd"):
    out = post(
        "/responder",
        {"perfil": perfil, "pergunta": "O que é um agente de IA?"},
    )
    print("===", perfil, "===")
    print(out["resposta"][:500], "..." if len(out["resposta"]) > 500 else "")
